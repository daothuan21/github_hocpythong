# %%
import turtle


t = turtle.Turtle()

t.forward(170)
t.right(90)
t.forward(190)
t.right(90)
t.forward(170)
t.right(90)
t.forward(190)

t.up()
t.goto(5,-5)
t.pendown()


for i in range(2):
    t.right(90)
    t.forward(160)
    t.right(90)
    t.forward(180)

    
    
for i in range(4):
    t.right(90)
    t.forward(20)
    t.right(90)
    t.forward(80)
    t.left(90)
    t.forward(20)
    t.left(90)
    t.forward(80)
    
t.left(90)
t.forward(160)
t.left(90)
t.forward(20)
t.left(90)

for i in range(4):
    t.forward(160)
    t.right(90)
    t.forward(20)
    t.right(90)
    t.forward(160)
    t.left(90)
    t.forward(20)
    t.left(90)

for i in range(4):
    t.forward(20)
    t.left(90)
    t.forward(80)   
    t.right(90)

    t.forward(20)
    t.right(90)
    t.forward(80)
    t.left(90)


t.up()
t.goto(105,-5)
t.pendown()
t.goto(65,-45)
t.goto(65,-5)

t.goto(65,-45)
t.goto(105,-45)
t.goto(65,-5)


t.up()
t.goto(105,-145)
t.pendown()
t.goto(65,-185)
t.goto(65,-145)
t.goto(105,-185)

turtle.done()
